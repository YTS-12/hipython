# %% [markdown]
# - 기본 자료형 : 정수형, 실수형, 숫자형, 문자형, 부을 형 boolean
# - 복합 자료형 : list, tuple, dictionary, set

# %% [markdown]
# # 기본자료형

# %% [markdown]
# ## int 정수형

# %%
20, type(20)
# Out:
# (20, int)

# %%
a=20 #10진수
a
# Out:
# 20

# %%
a = 0b101 # 2**3*0 + 2**2*1 + 2**1*0 + 2**0*1
a
# Out:
# 5

# %%
a = 0o10
b=0b1000
c=0x16d
a,b,c
# Out:
# (8, 8, 365)

# %% [markdown]
# ## float 실수형

# %%
b=3.14
type(b), b
# Out:
# (float, 3.14)

# %% [markdown]
# ## 지수의 표기
# 10e2

# %%
a = 10e2
a
# Out:
# 1000.0

# %%
a = 10e-2
a
# Out:
# 0.1

# %%
3.1415e9
# Out:
# 3141500000.0

# %% [markdown]
# ## boolean 부울형
#
# True == 1 == 참, False == 0 == 거짓    예약어

# %%
a = 10
a = 3.14
a = 3.14e5
a = True
b = False
a,b
# Out:
# (True, False)

# %%
type(a), type(b)
# Out:
# (bool, bool)

# %% [markdown]
# ### 논리연산, 비교연산

# %%
a == 0 # == 같다 비교연산자
# Out:
# False

# %%
a == 1
# Out:
# True

# %%
a == True
# Out:
# True

# %%
b = 1 
a and b, a, b
# Out:
# (1, True, 1)

# %%
# and : a,b 모두 참(1)일때 1, 아니면 0
# or : a,b 둘중 1개만 참(1)일 때 1
# not : True는 False로, False는 True로 반환

# %%
if (a and b) : 
    print('hello')
# Out:
# hello

# %%
int('50')
# Out:
# 50

# %%
float('50')
# Out:
# 50.0

# %%
bool('50')     # 0이 아니면 True
# Out:
# True

# %%
bool('0')
# Out:
# True

# %% [markdown]
# # 숫자형 연산

# %%
a=2
b=3
a+b, a-b, a*b, a/b, a//b, a%b     # // : 몫 구하기, % : 나머지
# Out:
# (5, -1, 6, 0.6666666666666666, 0, 2)

# %% [markdown]
# # 비교연산

# %%
a == b, a != b, a > b, a >= b   # != : 같지 않은지 비교
# Out:
# (False, True, False, False)

# %% [markdown]
# # 대입연산 =, +=, -=

# %%
a = 10
a += 2
a
# Out:
# 12

# %%
a = 10
a -= 2
a
# Out:
# 8

# %% [markdown]
# # 문자열 연산, 문자열 메소드, 문자열 슬라이싱

# %%
first_name = 'taesang'
last_name = 'yu'
first_name + last_name
# Out:
# 'taesangyu'

# %%
last_name == 'Yu'
# Out:
# False

# %%
last_name == 'Yu'.lower()   # 소문자 : lower, 대문자 : upper
# Out:
# True

# %%
last_name.upper()
# Out:
# 'YU'

# %%
last_name.capitalize()
# Out:
# 'Yu'

# %%
last_name.title()
# Out:
# 'Yu'

# %%
lyrics = """아기 상어 뚜루루 뚜루
귀여운 뚜루루 뚜루
바닷속 뚜루루 뚜루
아기 상어!
엄마 상어 뚜루루 뚜루
어여쁜 뚜루루 뚜루
바닷속 뚜루루 뚜루
엄마 상어!
아빠 상어 뚜루루 뚜루
힘이 센 뚜루루 뚜루
바닷속 뚜루루 뚜루
아빠 상어!
할머니 상어 (뚜루루 뚜루)
자상한 (뚜루루 뚜루)
바닷속 뚜루루 뚜루
할머니 상어!
할아버지 상어 (뚜루루 뚜루)
멋있는 (뚜루루 뚜루)
바닷속 뚜루루 뚜루
할아버지 상어!
우리는 뚜루루 뚜루
바다의 뚜루루 뚜루
사냥꾼 뚜루루 뚜루
상어 가족!
상어다 뚜루루 뚜루
도망쳐 뚜루루 뚜루
도망쳐 뚜루루 뚜루
숨자! 으악!
살았다 뚜루루 뚜루
살았다 뚜루루 뚜루
오늘도 뚜루루 뚜루
살았다 휴!
신난다 (뚜루루 뚜루)
신난다 (뚜루루 뚜루)
춤을 춰 뚜루루 뚜루
노래 끝! 오예!"""

target = "뚜루"
print(lyrics.count(target))
# Out:
# 54

# %%
주민등록번호 = '970528-1234567'
주민등록번호[0:6]
# Out:
# '970528'

# %%
주민등록번호.split('-')[0]
# Out:
# '970528'

# %%
jumin = '970528-1234567'
월 = jumin[2:4]
일 = jumin[4:6]
if jumin[0:2] == "00" : 
    print(월)
else : 
    print(일)
# Out:
# 28

# %%
jumin
# Out:
# '970528-1234567'

# %%
jumin[0]
# Out:
# '9'

# %%
jumin[1]
# Out:
# '7'

# %%
jumin[-1]
# Out:
# '7'

# %%
jumin[-2:]
# Out:
# '67'

# %%
jumin.split("-")[1][0]
# Out:
# '1'

# %%
jumin_new = jumin.replace('1','2')
jumin_new
# Out:
# '970528-2234567'

# %%
print("###############")
print("#"*10)
# Out:
# ###############
# ##########

# %% [markdown]
# # 인덱싱과 슬라이싱

# %%
text = "Python"
print(text[0:3])
print(text[2:])    
print(text[:4])    
print(text[-3:])  
print(text[::2])
print(text[1::3])
print(text[2])
# Out:
# Pyt
# thon
# Pyth
# hon
# Pto
# yo
# t

# %%
dir(text)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
'a'. encode('utf-8')
dec_value = 'a'.encode('utf-16')
dec_value
# Out:
# b'\xff\xfea\x00'

# %%
dec_value.decode('utf-16')
# Out:
# 'a'

# %%
# format()
# test_str = '99.99 dollars are worth us$ 100입니다.'
test_str = '{0:.4f} {1:s} are worth us$ {2:d}입니다.'
test_str.format(99.99, 'dollars', 100)
# Out:
# '99.9900 dollars are worth us$ 100입니다.'

# %%
num1=99
num2=100
str1='dollars'
test_str = f'{num1:.4f} {str1:s} are worth us$ {num2:d} 입니다.'
test_str
# Out:
# '99.0000 dollars are worth us$ 100 입니다.'

# %%
len(test_str)    #len 문자열 갯수확인(공백포함)
# Out:
# 38

# %%
email = 'aaa@gmail.com'
email_1 = 'aaa@gmail.com @@@@@ '
email_2 = ' aaa@jamil.com  '
len(email), len(email_1)
# Out:
# (13, 20)

# %%
email_1
# Out:
# 'aaa@gmail.com @@@@@ '

# %%
email_1.strip('@, ')
# Out:
# 'aaa@gmail.com'

# %%
len(email_1.strip('@, ')) , len(email_2.strip())    #strip() 메서드는 문자열의 양 끝에서 특정 문자를 제거
# Out:
# (13, 13)

# %%
lyrics.rfind('뚜루루')   #rfind() 메서드는 문자열 내에서 특정 문이나 문자열이 마지막으로 나타나는 위치
# Out:
# 377

# %%
lyrics[377:380]
# Out:
# '뚜루루'

# %% [markdown]
# # 문자열
# 1. 인덱싱, 슬라이싱, 멤버십
# 2. 문자열은 immutable "불변", 대소문자 구분한다.
# 3. 문자열은 코드를 지정, 인코딩, 디코딩, 유니코드(이모지), 한글
# 4. 문자열 +, *
# 5. 공백처리, 형식처리 등을 해야 한다.

# %%
import re
text = "파이썬    문자열    처리"
clean = re.sub(r"\s+"," ", text)
print(clean)
# Out:
# 파이썬 문자열 처리

# %%
tel_no = '010-1234-5678'
re.sub(r'\D', "",tel_no)
# Out:
# '01012345678'
