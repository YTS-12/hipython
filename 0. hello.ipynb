# %%
print("hello jupyter")
# Out:
# hello jupyter

# %%
a=154954
b=1974238
a+b
# Out:
# 2129192

# %%
a*b
# Out:
# 305916075052

# %%
3154953/6456
# Out:
# 488.68540892193306

# %%
123456789//2
# Out:
# 61728394

# %%
123456789%2
# Out:
# 1
