# %%
class Bicycle:
  def __init__(self, color):
    self.color = color
  def move(self):
    print(f"{self.color} 자전거가 앞으로 이동합니다.")

# %%
b1 = Bicycle('red')  #객체생성
b2 = Bicycle('blue')  #객체생성

# %%
b1.move()
b2.move()
# Out:
# red 자전거가 앞으로 이동합니다.
# blue 자전거가 앞으로 이동합니다.
